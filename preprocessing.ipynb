# %% [markdown]
# ---
# # H515 - Statistical Learning - Course Project
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_original = pd.read_csv("Melbourne_housing_FULL.csv")

# %% [markdown]
# ## Original Data

# %%
df_original.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
#  17  Lattitude      26881 non-null  float64
#  18  Longtitude     26881 non-null  float64
#  19  Regionname     34854 non-null  object
#  20  Propertycount  34854 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
df_original.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# std        0.724212      1.010771    3398.841946     401.26706     37.328178
# min        0.000000      0.000000       0.000000       0.00000   1196.000000
# 25%        1.000000      1.000000     224.000000     102.00000   1940.000000
# 50%        2.000000      2.000000     521.000000     136.00000   1970.000000
# 75%        2.000000      2.000000     670.000000     188.00000   2000.000000
# max       12.000000     26.000000  433014.000000   44515.00000   2106.000000
#
#           Lattitude    Longtitude  Propertycount
# count  26881.000000  26881.000000   34854.000000
# mean     -37.810634    145.001851    7572.888306
# std        0.090279      0.120169    4428.090313
# min      -38.190430    144.423790      83.000000
# 25%      -37.862950    144.933500    4385.000000
# 50%      -37.807600    145.007800    6763.000000
# 75%      -37.754100    145.071900   10412.000000
# max      -37.390200    145.526350   21650.000000

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### NA Values

# %%
df_original.shape
# Out:
# (34857, 21)

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
#  17  Lattitude      26881 non-null  float64
#  18  Longtitude     26881 non-null  float64
#  19  Regionname     34854 non-null  object
#  20  Propertycount  34854 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
df_original.drop(columns=["BuildingArea", "YearBuilt"], axis=1, inplace=True)
df = df_original.dropna()

df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 5  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 6  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 1  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 4  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 5  4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 6  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# 1  Yarra City Council   -37.7996    144.9984  Northern Metropolitan
# 2  Yarra City Council   -37.8079    144.9934  Northern Metropolitan
# 4  Yarra City Council   -37.8093    144.9944  Northern Metropolitan
# 5  Yarra City Council   -37.7969    144.9969  Northern Metropolitan
# 6  Yarra City Council   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount
# 1         4019.0
# 2         4019.0
# 4         4019.0
# 5         4019.0
# 6         4019.0

# %%
df.shape
# Out:
# (17679, 19)

# %% [markdown]
# ### Duplicates

# %%
duplicated = df.duplicated(subset=("Lattitude", "Longtitude", "Date"), keep="first")

df[duplicated].head()
# Out:
#               Suburb          Address  Rooms Type      Price Method   SellerG  \
# 3533     Collingwood   2/79 Oxford St      2    u   855000.0      S    Nelson
# 3540     Collingwood   6/78 Oxford St      2    u   910000.0      S    Jellis
# 5358        Hawthorn  318/6 Lisson Gr      1    u   485000.0      S  Marshall
# 7829  Port Melbourne  133/95 Rouse St      2    u  1070000.0      S        RT
# 8045         Prahran    49 Clifton St      2    h   765000.0      S    Beller
#
#             Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 3533   3/09/2016       1.6    3066.0       2.0       1.0  1.0    2886.0
# 3540   4/03/2017       1.6    3066.0       2.0       1.0  1.0       0.0
# 5358  28/08/2016       4.6    3122.0       2.0       1.0  1.0       0.0
# 7829  10/09/2016       3.8    3207.0       2.0       2.0  1.0       0.0
# 8045  19/11/2016       4.5    3181.0       2.0       1.0  0.0      98.0
#
#                    CouncilArea  Lattitude  Longtitude             Regionname  \
# 3533        Yarra City Council   -37.8042    144.9845  Northern Metropolitan
# 3540        Yarra City Council   -37.8035    144.9850  Northern Metropolitan
# 5358   Boroondara City Council   -37.8264    145.0270  Southern Metropolitan
# 7829    Melbourne City Council   -37.8435    144.9415  Southern Metropolitan
# 8045  Stonnington City Council   -37.8501    144.9953  Southern Metropolitan
#
#       Propertycount
# 3533         4553.0
# 3540         4553.0
# 5358        11308.0
# 7829         8648.0
# 8045         7717.0

# %%
df = df[~duplicated]

# %% [markdown]
# ### Removing Outliers

# %% [markdown]
# #### YearBuilt

# %%
def plot_histogram(dataframe, column, figsize=None):

    if figsize is not None:
        plt.figure(figsize=figsize)
    sns.histplot(dataframe[column])
    plt.title(f"Histogram of {column} Column")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
#plot_histogram(df, "YearBuilt", (10, 8))

# %%
#built_before_1800 = df["YearBuilt"] < 1800
#df[built_before_1800]

# %%
#df = df[~built_before_1800]

# %% [markdown]
# #### BuildingArea

# %%
# build_eq_zero = (df["BuildingArea"] == 0)
# print(f"Properties with Zero Building Area - {sum(build_eq_zero)}")

# df = df[~build_eq_zero]

# %% [markdown]
# #### Landsize

# %%
land_eq_zero = (df["Landsize"] == 0)
print(f"Properties with Zero Land Size - {sum(land_eq_zero)}")

df = df[~land_eq_zero]
# Out:
# Properties with Zero Land Size - 1930

# %%
plot_histogram(df, "Landsize", (10, 8))

# %%
plot_histogram(df, "Price", (10, 8))

# %%
percentile_value = df["Landsize"].quantile(.95)
print(percentile_value)

gt_95_prec_land = (df["Landsize"] > percentile_value)
df[gt_95_prec_land].head()
# Out:
# 1011.4499999999989
#            Suburb              Address  Rooms Type      Price Method  \
# 41     Abbotsford  138/56 Nicholson St      3    u  1090000.0      S
# 86   Airport West          3 Deidre Ct      3    h   895000.0     PI
# 235        Altona           29 Rose St      4    h  1780000.0     SP
# 388      Armadale        526 Orrong Rd      4    h  3000000.0     VB
# 392      Armadale       9/19 Mercer Rd      3    u   735000.0     PI
#
#       SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 41     Jellis  18/03/2017       2.5    3067.0       3.0       2.0  2.0
# 86    Rendina  10/09/2016      13.5    3042.0       3.0       1.0  6.0
# 235      Greg   4/06/2016      13.8    3018.0       4.0       3.0  6.0
# 388    Jellis   4/06/2016       6.3    3143.0       4.0       2.0  2.0
# 392  Marshall   7/05/2016       6.3    3143.0       3.0       2.0  1.0
#
#      Landsize                 CouncilArea  Lattitude  Longtitude  \
# 41     4290.0          Yarra City Council   -37.8078    144.9965
# 86     1063.0  Moonee Valley City Council   -37.7249    144.8728
# 235    1057.0    Hobsons Bay City Council   -37.8681    144.8190
# 388    1581.0    Stonnington City Council   -37.8580    145.0111
# 392    2113.0    Stonnington City Council   -37.8543    145.0262
#
#                 Regionname  Propertycount
# 41   Northern Metropolitan         4019.0
# 86    Western Metropolitan         3464.0
# 235   Western Metropolitan         5301.0
# 388  Southern Metropolitan         4836.0
# 392  Southern Metropolitan         4836.0

# %%
percentile_value = df["Landsize"].quantile(.995)
print(percentile_value)

gt_995_prec_land = (df["Landsize"] > percentile_value)
df[gt_995_prec_land].head()
# Out:
# 4946.86999999997
#               Suburb              Address  Rooms Type      Price Method  \
# 1198    Balwyn North          9 Gildan St      3    h  2000000.0     VB
# 3539     Collingwood      4/170 Oxford St      3    u   950000.0      S
# 4149  Essendon North          1 Dudley St      3    h  1425000.0      S
# 4415       Footscray    13/2 Saltriver Pl      3    u   674000.0      S
# 6195       Maidstone  17/46 Eucalyptus Dr      2    u   352500.0      S
#
#             SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1198            Kay  28/08/2016       9.2    3104.0       3.0       1.0  2.0
# 3539         Jellis   4/03/2017       1.6    3066.0       3.0       2.0  1.0
# 4149        McGrath  25/02/2017       9.4    3041.0       3.0       2.0  2.0
# 4415         Jellis  11/02/2017       6.4    3011.0       3.0       2.0  1.0
# 6195  hockingstuart  18/03/2017       9.2    3012.0       2.0       1.0  1.0
#
#       Landsize                 CouncilArea  Lattitude  Longtitude  \
# 1198   75100.0     Boroondara City Council   -37.8002    145.0700
# 3539   15900.0          Yarra City Council   -37.8035    144.9850
# 4149   10100.0  Moonee Valley City Council   -37.7376    144.8954
# 4415    8680.0    Maribyrnong City Council   -37.8016    144.9082
# 6195   15100.0    Maribyrnong City Council   -37.7795    144.8729
#
#                  Regionname  Propertycount
# 1198  Southern Metropolitan         7809.0
# 3539  Northern Metropolitan         4553.0
# 4149   Western Metropolitan         1308.0
# 4415   Western Metropolitan         7570.0
# 6195   Western Metropolitan         3873.0

# %%
df[df["Landsize"] > 30000]
# Out:
#                Suburb            Address  Rooms Type      Price Method  \
# 1198     Balwyn North        9 Gildan St      3    h  2000000.0     VB
# 6591      Maribyrnong    44/2 Horizon Dr      2    u   495000.0      S
# 8599        Reservoir       14 Beenak St      3    h   572000.0      S
# 15109     Maribyrnong     2/6 Horizon Dr      2    u   585000.0      S
# 16539          Silvan        1 Parker Rd      4    h  1070000.0      S
# 17293          Silvan      16 Eleanor Dr      3    h  1085000.0      S
# 18036         Fitzroy        389 Gore St      3    h  2700000.0     VB
# 18531        Gisborne     21 Braeside Rd      4    h   807000.0      S
# 22632    New Gisborne     71 Hamilton Rd      5    h  1355000.0      S
# 24800        Wildwood    430 Wildwood Rd      5    h  1030000.0      S
# 25964  Gisborne South      31 Stanton Ct      3    h   930000.0      S
# 26868    Bullengarook         65 Webb Rd      4    h  1050000.0     PI
# 28694  Gisborne South      47 Tweddle Rd      4    h  1350000.0     SA
# 32220    Wandin North  237 Warburton Hwy      4    h  1150000.0     PI
# 34055    Bullengarook      11 Dohoney Rd      4    h   865000.0      S
#
#          SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1198         Kay  28/08/2016       9.2    3104.0       3.0       1.0  2.0
# 6591        Brad  18/03/2017       8.7    3032.0       2.0       2.0  2.0
# 8599         Ray  23/04/2016      11.2    3073.0       3.0       1.0  2.0
# 15109       Brad   3/06/2017       4.3    3032.0       2.0       2.0  2.0
# 16539        Ray  24/06/2017      34.6    3795.0       4.0       2.0  3.0
# 17293  Harcourts  27/05/2017      34.6    3795.0       3.0       2.0  2.0
# 18036        Kay  12/08/2017       2.1    3065.0       3.0       3.0  1.0
# 18531      Raine  15/07/2017      45.9    3437.0       4.0       2.0  3.0
# 22632      Raine  23/09/2017      48.1    3438.0       5.0       3.0  5.0
# 24800         RE  14/10/2017      31.7    3429.0       5.0       2.0  2.0
# 25964      Raine  28/10/2017      45.9    3437.0       3.0       2.0  4.0
# 26868      Raine  11/11/2017      45.9    3437.0       4.0       2.0  1.0
# 28694         RT  25/11/2017      45.9    3437.0       4.0       2.0  8.0
# 32220        Max   3/03/2018      35.2    3139.0       4.0       2.0  2.0
# 34055      Raine  24/02/2018      45.9    3437.0       4.0       2.0  0.0
#
#        Landsize                   CouncilArea  Lattitude  Longtitude  \
# 1198    75100.0       Boroondara City Council  -37.80020   145.07000
# 6591    37000.0      Maribyrnong City Council  -37.77520   144.89250
# 8599    41400.0          Darebin City Council  -37.71040   145.02570
# 15109   37000.0      Maribyrnong City Council  -37.77518   144.89254
# 16539   38490.0    Yarra Ranges Shire Council  -37.83229   145.43003
# 17293   76000.0    Yarra Ranges Shire Council  -37.84739   145.47052
# 18036  433014.0            Yarra City Council  -37.79751   144.98309
# 18531   40468.0  Macedon Ranges Shire Council  -37.50929   144.56444
# 22632   44500.0  Macedon Ranges Shire Council  -37.45392   144.58864
# 24800   89030.0             Hume City Council  -37.60400   144.80604
# 25964   40468.0  Macedon Ranges Shire Council  -37.54812   144.63257
# 26868  146699.0  Macedon Ranges Shire Council  -37.47540   144.51300
# 28694   40469.0  Macedon Ranges Shire Council  -37.54300   144.59690
# 32220   40500.0    Yarra Ranges Shire Council  -37.77000   145.41470
# 34055   42800.0  Macedon Ranges Shire Council  -37.47154   144.53828
#
#                   Regionname  Propertycount
# 1198   Southern Metropolitan         7809.0
# 6591    Western Metropolitan         4918.0
# 8599   Northern Metropolitan        21650.0
# 15109   Western Metropolitan         4918.0
# 16539       Eastern Victoria          457.0
# 17293       Eastern Victoria          457.0
# 18036  Northern Metropolitan         5825.0
# 18531      Northern Victoria         3376.0
# 22632      Northern Victoria          849.0
# 24800   Western Metropolitan           83.0
# 25964      Northern Victoria          290.0
# 26868      Northern Victoria          249.0
# 28694      Northern Victoria          290.0
# 32220       Eastern Victoria         1130.0
# 34055      Northern Victoria          249.0

# %%
land_size_up_threshold = 10000
gt_10000_land = (df["Landsize"] > land_size_up_threshold)

df = df[~gt_10000_land]

# %%
(df["Landsize"] < 55).sum()
# Out:
# 39

# %%
land_size_lo_threshold = 55
lt_55_land = (df["Landsize"] < land_size_lo_threshold)

df = df[~lt_55_land]

# %% [markdown]
# ### Column Selection

# %%
print("Columns Unique Value Counts - \n")
for column in df.columns:
    print(f"{column} -", df.loc[:, column].nunique())
# Out:
# Columns Unique Value Counts -
#
# Suburb - 327
# Address - 15376
# Rooms - 10
# Type - 3
# Price - 2342
# Method - 5
# SellerG - 292
# Date - 78
# Distance - 206
# Postcode - 200
# Bedroom2 - 13
# Bathroom - 10
# Car - 13
# Landsize - 1485
# CouncilArea - 33
# Lattitude - 9080
# Longtitude - 9778
# Regionname - 8
# Propertycount - 323

# %% [markdown]
# Columns **not** being used - `Suburb`, `Address`, `Method`, `SellerG`, `Postcode`, `CouncilArea` and `Regionname`

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### BuildtoLandArea

# %%
#df["BuildtoLandArea"] = df["Landsize"] / df["BuildingArea"]

# %% [markdown]
# #### Property Count

# %%
percentiles = [0, 20, 40, 60, 80, 100]
bin_edges = np.percentile(df['Propertycount'], percentiles)

bin_labels = ["Highly Sparse", "Below Avg.", "Average", "Above Avg.", "Highly Dense"]
df["Propertycount_Bins"] = pd.cut(df["Propertycount"], bins=bin_edges, labels=bin_labels, include_lowest=True)

# %% [markdown]
# #### Bathroom

# %%
bath_zero = (df["Bathroom"] == 0)

df = df[~bath_zero]

# %% [markdown]
# #### BedtoBath

# %%
df["BedtoBath"] = df["Bedroom2"] / df["Bathroom"]

# %%
num_columns = ["Price", "Distance", "Landsize", "Lattitude", "Longtitude", "BedtoBath"]
cat_columns = ["Rooms", "Type", "Bedroom2", "Bathroom", "Car", "Propertycount_Bins"]

# %%
plot_histogram(df, "Landsize", (10, 8))

# %%
# tail_heavy_columns = ["Landsize", ]
# df[tail_heavy_columns] = df[tail_heavy_columns].apply(lambda x: np.log(x+1))

# plot_histogram(df, "Landsize", (10, 8))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        ("numerical", StandardScaler(), num_columns),
        ("categorical", OneHotEncoder(handle_unknown='ignore'), cat_columns)
    ]
)

# %%
df_preprocessed = preprocessor.fit_transform(df)

df_preprocessed = df_preprocessed.toarray()
print(df_preprocessed.shape)

np.save("X.npy", df_preprocessed)
# Out:
# (15641, 59)

# %%
np.save("y.npy", df["Price"])

# %%
# pd.DataFrame(df_preprocessed)
# pd.DataFrame(df_preprocessed).to_csv("preprocessed_data.csv", index=False)
